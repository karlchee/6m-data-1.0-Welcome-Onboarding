# %% [markdown]
# <a href="https://colab.research.google.com/github/karlchee/6m-data-1.0-Welcome-Onboarding/blob/main/Github_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.
